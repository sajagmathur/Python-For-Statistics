# %%
import os
import numpy as np
import pandas as pd
df_demo = pd.read_csv('C:\\Users\\sajag177350\\Python For Statistics\\Reference\\500_Person_Gender_Height_Weight_Index.csv',delimiter=',',header='infer')
df_demo.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %% [markdown]
# ## 1. Basic Data Exploration
# Identify the number of rows and columns in the dataset.
# Check for missing values.
# Identify the data types of each column

# %%
df_demo.shape
# Out:
# (500, 4)

# %%
datatypes = df_demo.dtypes
print(datatypes)
# Out:
# Gender    object
# Height     int64
# Weight     int64
# Index      int64
# dtype: object

# %%
df_demo.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# Index     0
# dtype: int64

# %%
print("No Null Values")
# Out:
# No Null Values

# %% [markdown]
# ###  2. Summary Statistics
# Calculate mean, median, and mode for Height, Weight, and Index.
# Identify the minimum and maximum values.
# Compute the standard deviation and variance for numerical columns.

# %%
heightmean = df_demo['Height'].mean()
WeightMean = df_demo['Weight'].mean()
Indexmean = df_demo['Index'].mean()
print("Mean Height: ",heightmean)
print("Mean Weight: ",WeightMean)
print("Mean Index: ",Indexmean)
# Out:
# Mean Height:  169.944
# Mean Weight:  106.0
# Mean Index:  3.748

# %%
heightmed = df_demo['Height'].median()
WeightMed = df_demo['Weight'].median()
Indexmed = df_demo['Index'].median()
print("Median Height: ",heightmed)
print("Median Weight: ",WeightMed)
print("Median Index: ",Indexmed)
# Out:
# Median Height:  170.5
# Median Weight:  106.0
# Median Index:  4.0

# %%
heightmod = df_demo['Height'].mode()[0]
WeightMod = df_demo['Weight'].mode()[0]
Indexmod = df_demo['Index'].mode()[0]
print("Mode Height: ",heightmod)
print("Mode Weight: ",WeightMod)
print("Mode Index: ",Indexmod)
# Out:
# Mode Height:  188
# Mode Weight:  50
# Mode Index:  5

# %%
heightmin = df_demo['Height'].min()
Weightmin = df_demo['Weight'].min()
Indexmin = df_demo['Index'].min()
print("Minimum Height: ",heightmin)
print("Minimum Weight: ",Weightmin)
print("Minimum Index: ",Indexmin)
# Out:
# Minimum Height:  140
# Minimum Weight:  50
# Minimum Index:  0

# %%
heightmax = df_demo['Height'].max()
Weightmax = df_demo['Weight'].max()
Indexmax = df_demo['Index'].max()
print("Maximum Height: ",heightmax)
print("Maximum Weight: ",Weightmax)
print("Maximum Index: ",Indexmax)
# Out:
# Maximum Height:  199
# Maximum Weight:  160
# Maximum Index:  5

# %%
heightstd = df_demo['Height'].std()
Weightstd = df_demo['Weight'].std()
Indexstd = df_demo['Index'].std()
print("Std Height: ",heightstd)
print("Std Weight: ",Weightstd)
print("Std Index: ",Indexstd)
# Out:
# Std Height:  16.37526067959376
# Std Weight:  32.38260746964435
# Std Index:  1.3550528907291186

# %%
heightvar = df_demo['Height'].var()
Weightvar = df_demo['Weight'].var()
Indexvar = df_demo['Index'].var()
print("Var Height: ",heightvar)
print("Var Weight: ",Weightvar)
print("Var Index: ",Indexvar)
# Out:
# Var Height:  268.1491623246496
# Var Weight:  1048.633266533066
# Var Index:  1.8361683366733408

# %% [markdown]
# ## 3. Distribution Analysis
# Analyze the distribution of Height and Weight.
# Identify skewness and check whether the data is normally distributed.
# Identify outliers using box plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sb
# Get the variable to examine
var_data = df_demo['Height']

# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.hist(var_data)

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the figure
fig.show()
# Out:
# C:\Users\sajag177350\AppData\Local\Temp\1\ipykernel_9212\1742900696.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Get the variable to examine
var_data = df_demo['Weight']

# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.hist(var_data)

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the figure
fig.show()
# Out:
# C:\Users\sajag177350\AppData\Local\Temp\1\ipykernel_9212\329875599.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#Identification of skewness
def show_density(var_data):
    from matplotlib import pyplot as plt

    fig = plt.figure(figsize=(10,4))

    # Plot density
    var_data.plot.density()

    # Add titles and labels
    plt.title('Data Density')

    # Show the mean, median, and mode
    plt.axvline(x=var_data.mean(), color = 'cyan', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.median(), color = 'red', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.mode()[0], color = 'yellow', linestyle='dashed', linewidth = 2)

    # Show the figure
    plt.show()

# Get the density of Grade
col = df_demo['Weight']
show_density(col)

# %%
col1 = df_demo["Height"]
# Call the function
show_density(col1)

# %%
# Create a function that we can re-use
def show_distribution(var_data):
    from matplotlib import pyplot as plt

    # Get statistics
    min_val = var_data.min()
    max_val = var_data.max()
    mean_val = var_data.mean()
    med_val = var_data.median()
    mod_val = var_data.mode()[0]

    print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                            mean_val,
                                                                                            med_val,
                                                                                            mod_val,
                                                                                            max_val))

    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize = (10,4))

    # Plot the histogram   
    ax[0].hist(var_data)
    ax[0].set_ylabel('Frequency')

    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

    # Plot the boxplot   
    ax[1].boxplot(var_data, vert=False)
    ax[1].set_xlabel('Value')

    # Add a title to the Figure
    fig.suptitle('Data Distribution')

    # Show the figure
    fig.show()

# Get the variable to examine
col = df_demo['Weight']
# Call the function
show_distribution(col)

col = df_demo['Height']
# Call the function
show_distribution(col)
# Out:
# Minimum:50.00
# Mean:106.00
# Median:106.00
# Mode:50.00
# Maximum:160.00
#
# Minimum:140.00
# Mean:169.94
# Median:170.50
# Mode:188.00
# Maximum:199.00
# C:\Users\sajag177350\AppData\Local\Temp\1\ipykernel_9212\649904784.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\sajag177350\AppData\Local\Temp\1\ipykernel_9212\649904784.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#Excluding outliers

# %%
q01 = df_demo.Height.quantile(0.01)
# Get the variable to examine
col = df_demo[df_demo.Height>q01]['Height']
# Call the function
show_distribution(col)
# Out:
# Minimum:141.00
# Mean:170.43
# Median:171.00
# Mode:188.00
# Maximum:199.00
# C:\Users\sajag177350\AppData\Local\Temp\1\ipykernel_9212\649904784.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
q01 = df_demo.Weight.quantile(0.01)
# Get the variable to examine
col = df_demo[df_demo.Weight>q01]['Weight']
# Call the function
show_distribution(col)
# Out:
# Minimum:51.00
# Mean:107.03
# Median:107.00
# Mode:80.00
# Maximum:160.00
# C:\Users\sajag177350\AppData\Local\Temp\1\ipykernel_9212\649904784.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#Data Distribution post outlier treatment

# %%
col1 = df_demo["Height"]
# Call the function
show_density(col1)

# %%
col1 = df_demo["Weight"]
# Call the function
show_density(col1)

#thus, the data is skewed

# %% [markdown]
# ### 4. Gender-Based Analysis
# Compute the average height and weight for males and females separately.
# Compare the distribution of the Index across genders.
# Analyze the spread of Height and Weight for each gender.

# %%
df2 = df_demo.groupby(['Gender']).mean()
df2 = df2.drop('Index',axis = 'columns')
print(df2)
# Out:
#             Height      Weight
# Gender
# Female  170.227451  105.698039
# Male    169.648980  106.314286

# %%
dfmale = df_demo[df_demo["Gender"] == "Male"]
dffemale = df_demo[df_demo["Gender"]=="Female"]
dfmale.head()
# Out:
#   Gender  Height  Weight  Index
# 0   Male     174      96      4
# 1   Male     189      87      2
# 4   Male     149      61      3
# 5   Male     189     104      3
# 6   Male     147      92      5

# %%
dffemale.head()
# Out:
#     Gender  Height  Weight  Index
# 2   Female     185     110      4
# 3   Female     195     104      3
# 9   Female     169     103      4
# 11  Female     159      80      4
# 12  Female     192     101      3

# %%
col1 = dfmale["Index"]
# Call the function
show_density(col1)

# %%
col1 = dffemale["Index"]
# Call the function
show_density(col1)

# %%
col1 = dfmale["Height"]
# Call the function
show_density(col1)

# %%
col1 = dffemale["Height"]
# Call the function
show_density(col1)

# %%
col1 = dfmale["Weight"]
# Call the function
show_density(col1)

# %%
col1 = dffemale["Weight"]
# Call the function
show_density(col1)

# %% [markdown]
# ### 5. Correlation Analysis
# Find the correlation between Height and Weight.
# Analyze how Weight is related to the Index value.

# %%
df_demo.Height.corr(df_demo.Weight)
# Out:
# 0.00044594512830535896

# %%
df_demo.Weight.corr(df_demo.Index)
# Out:
# 0.8045690944191751

# %% [markdown]
# ### 6. Categorical Analysis
# Count the number of males and females in the dataset.
# Find the percentage of each Index category.

# %%
df2 = df_demo.groupby(['Gender']).count()
df2 = df2.drop('Index',axis = 'columns')
print(df2)
# Out:
#         Height  Weight
# Gender
# Female     255     255
# Male       245     245

# %%
index_counts  = df_demo['Index'].value_counts()
total_entries = len(df_demo)
index_percentages = (index_counts / total_entries) * 100
print(index_percentages)
# Out:
# Index
# 5    39.6
# 4    26.0
# 2    13.8
# 3    13.6
# 1     4.4
# 0     2.6
# Name: count, dtype: float64
